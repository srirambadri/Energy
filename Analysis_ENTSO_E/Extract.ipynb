# %%
from entsoe import EntsoePandasClient
import pandas as pd
import numpy as np
import plotly.express as px
import datetime
import plotly.graph_objects as go
import random
import warnings

# Suppress FutureWarning messages
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None 

client = EntsoePandasClient(api_key='API-KEY')

start = pd.Timestamp('20230101', tz='Europe/Brussels')
end = pd.Timestamp('20240101', tz='Europe/Brussels')
country_code = 'DE'  # Germany
# country_code_from = 'FR'  # France
# country_code_to = 'DE_LU' # Germany-Luxembourg
type_marketagreement_type = 'A01'
contract_marketagreement_type = "A01"
process_type = 'A51'

# %%
def convert_time(df):

    if " - " in df.index:
        # Split the time interval into start and end times
        df["Start Time"] = df.index.str.split(" - ", expand=True)[0]
        # Convert the "Start Time" to datetime
        df["Start Time"] = pd.to_datetime(df["Start Time"], format="mixed")
        df.index = df["Start Time"]
    else:
        # Convert the time data to datetime
        df.index = pd.to_datetime(df.index, format="mixed")

    return df

# %%
def display_stats(df_read):


    for column in df_read.columns:
        # Compute descriptive statistics for the current column
        stats = df_read[column].describe()

        # Construct the summary text with markdown formatting
        summary_text = f"""
        ### Statistics for {column}
        **Count**: {stats['count']} data points.\n
        **Mean**: The average is {stats['mean']:.2f}.\n
        **Standard Deviation**: The standard deviation is {stats['std']:.2f}, which indicates variability.\n
        **Minimum**: The smallest observed value is {stats['min']:.2f}.\n
        **25th Percentile**: 25% of the values are {stats['25%']:.2f} or less.\n
        **50th Percentile (Median)**: The median value is {stats['50%']:.2f}.\n
        **75th Percentile**: 75% of the values are {stats['75%']:.2f} or less.\n
        **Maximum**: The largest observed value is {stats['max']:.2f}.
        """

        # Display the summary
        print(summary_text)

# %%
def filter_data(df,start_date,end_date):
    
    # Filter the DataFrame for the selected date range
    df_days_of_interest = df.loc[
        start_date.strftime("%Y-%m-%d") : end_date.strftime("%Y-%m-%d")
    ]
    return df_days_of_interest

# %%
def visualize_data_by_date_range(df_read):
    
    # Create a line plot for each column in the DataFrame
    fig2 = go.Figure()
    for column in df_read.columns:
        fig2.add_trace(
            go.Scatter(
                x=df_read.index, y=df_read[column], name=column
            )
        )
    # Display the figure
    fig2.show()

# %%
def visualise_data(df_read):

    fig3 = go.Figure()
    fig4 = go.Figure()
    fig5 = go.Figure()

    for column in df_read.columns:
        # Generate a random color
        random_color = 'rgb(%d, %d, %d)' % (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))

        # Resample and calculate mean for each day
        daily_mean = df_read[column].resample('D').mean()

        # Resample for monthly peak and mean
        monthly_peak = df_read[column].resample('M').max()
        monthly_mean = df_read[column].resample('M').sum()
        monthly_change = monthly_mean.diff()

        # Add traces for daily mean, monthly peak, and monthly change
        fig3.add_trace(go.Scatter(x=daily_mean.index, y=daily_mean, name=column, line=dict(color=random_color)))
        fig4.add_trace(go.Bar(x=monthly_peak.index.strftime('%B'), y=monthly_peak, name=column, marker_color=random_color))
        fig5.add_trace(go.Bar(x=monthly_change.index, y=monthly_change, name=f'Monthly Change - {column}', marker_color=random_color))

    # Update layout for each figure
    fig3.update_layout(title={'text': "Daily Load "})
    fig4.update_layout(title='Monthly Peak Values', xaxis_title='Month', yaxis_title='Peak Value', barmode='group')
    fig5.update_layout(title='Monthly Load Change', xaxis_title='Date', yaxis_title='Change in Aggregate Load', barmode='group')

    fig3.show()
    fig4.show()
    fig5.show()

# %%
df_read=client.query_generation(country_code, start=start, end=end, psr_type=None)
df_read = df_read.drop('Actual Consumption', axis = 1, level = 1)
df_read = df_read.droplevel(1, axis=1) 
df_read = convert_time(df_read)

# %%
visualise_data(df_read)
#display_stats(df)

# %%
# Select a range of dates
start_date = datetime.date(2023, 6, 1)
end_date = datetime.date(2023, 7, 1)
df_filtered = filter_data(df_read,start_date,end_date)

# %%
visualize_data_by_date_range(df_filtered)
df_filtered['hour'] = df_filtered.index.hour
df_s = df_filtered.groupby(['hour']).mean().transpose()
(df_s
 .fillna(0)
 .style
     .format(precision=0, thousands=',')
     .background_gradient(cmap='Reds', axis=1)
)
# Out:
# <style type="text/css">
# #T_634b0_row0_col0, #T_634b0_row16_col11 {
#   background-color: #fcbda4;
#   color: #000000;
# }
# #T_634b0_row0_col1 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_634b0_row0_col2, #T_634b0_row12_col10 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_634b0_row0_col3, #T_634b0_row7_col17, #T_634b0_row9_col11 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_634b0_row0_col4, #T_634b0_row2_col6, #T_634b0_row4_col1, #T_634b0_row9_col12 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_634b0_row0_col5, #T_634b0_row7_col18 {
#   background-color: #fcb095;
#   color: #000000;
# }
# #T_634b0_row0_col6 {
#   background-color: #eb372a;
#   color: #f1f1f1;
# }
# #T_634b0_row0_col7, #T_634b0_row6_col7 {
#   background-color: #bb141a;
#   color: #f1f1f1;
# }
# #T_634b0_row0_col8, #T_634b0_row4_col18 {
#   background-color: #cb181d;
#   color: #f1f1f1;
# }
# #T_634b0_row0_col9, #T_634b0_row15_col5 {
#   background-color: #fa6547;
#   color: #f1f1f1;
# }
# #T_634b0_row0_col10, #T_634b0_row7_col6 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_634b0_row0_col11 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_634b0_row0_col12, #T_634b0_row3_col16, #T_634b0_row6_col18 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_634b0_row0_col13, #T_634b0_row8_col4 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_634b0_row0_col14, #T_634b0_row1_col14, #T_634b0_row2_col7, #T_634b0_row3_col15, #T_634b0_row4_col13, #T_634b0_row5_col6, #T_634b0_row6_col16, #T_634b0_row7_col13, #T_634b0_row7_col14, #T_634b0_row8_col5, #T_634b0_row9_col3, #T_634b0_row10_col0, #T_634b0_row10_col1, #T_634b0_row10_col2, #T_634b0_row10_col3, #T_634b0_row10_col4, #T_634b0_row10_col5, #T_634b0_row10_col6, #T_634b0_row10_col7, #T_634b0_row10_col8, #T_634b0_row10_col9, #T_634b0_row10_col10, #T_634b0_row10_col11, #T_634b0_row10_col12, #T_634b0_row10_col13, #T_634b0_row10_col14, #T_634b0_row10_col15, #T_634b0_row10_col16, #T_634b0_row10_col17, #T_634b0_row10_col18, #T_634b0_row10_col19, #T_634b0_row10_col20, #T_634b0_row10_col21, #T_634b0_row10_col22, #T_634b0_row10_col23, #T_634b0_row11_col15, #T_634b0_row12_col11, #T_634b0_row13_col0, #T_634b0_row13_col1, #T_634b0_row13_col2, #T_634b0_row13_col3, #T_634b0_row13_col4, #T_634b0_row13_col21, #T_634b0_row13_col22, #T_634b0_row13_col23, #T_634b0_row14_col7, #T_634b0_row14_col8, #T_634b0_row14_col9, #T_634b0_row15_col12, #T_634b0_row16_col9 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_634b0_row0_col15, #T_634b0_row4_col3, #T_634b0_row4_col14 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_634b0_row0_col16 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_634b0_row0_col17, #T_634b0_row11_col0 {
#   background-color: #fca78b;
#   color: #000000;
# }
# #T_634b0_row0_col18, #T_634b0_row1_col1 {
#   background-color: #ea362a;
#   color: #f1f1f1;
# }
# #T_634b0_row0_col19, #T_634b0_row8_col12, #T_634b0_row15_col20 {
#   background-color: #940b13;
#   color: #f1f1f1;
# }
# #T_634b0_row0_col20, #T_634b0_row1_col21, #T_634b0_row2_col0, #T_634b0_row3_col21, #T_634b0_row4_col20, #T_634b0_row5_col18, #T_634b0_row6_col5, #T_634b0_row7_col20, #T_634b0_row8_col11, #T_634b0_row9_col20, #T_634b0_row11_col8, #T_634b0_row12_col5, #T_634b0_row13_col12, #T_634b0_row14_col20, #T_634b0_row15_col21, #T_634b0_row16_col23 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_634b0_row0_col21 {
#   background-color: #860811;
#   color: #f1f1f1;
# }
# #T_634b0_row0_col22, #T_634b0_row9_col19, #T_634b0_row15_col2 {
#   background-color: #cf1c1f;
#   color: #f1f1f1;
# }
# #T_634b0_row0_col23, #T_634b0_row4_col7, #T_634b0_row8_col13 {
#   background-color: #fb6c4c;
#   color: #f1f1f1;
# }
# #T_634b0_row1_col0, #T_634b0_row9_col7 {
#   background-color: #ca181d;
#   color: #f1f1f1;
# }
# #T_634b0_row1_col2 {
#   background-color: #f34935;
#   color: #f1f1f1;
# }
# #T_634b0_row1_col3 {
#   background-color: #f6553c;
#   color: #f1f1f1;
# }
# #T_634b0_row1_col4, #T_634b0_row3_col8, #T_634b0_row9_col8 {
#   background-color: #f5533b;
#   color: #f1f1f1;
# }
# #T_634b0_row1_col5, #T_634b0_row16_col5 {
#   background-color: #ef3c2c;
#   color: #f1f1f1;
# }
# #T_634b0_row1_col6, #T_634b0_row7_col19, #T_634b0_row9_col22, #T_634b0_row12_col21 {
#   background-color: #d52221;
#   color: #f1f1f1;
# }
# #T_634b0_row1_col7, #T_634b0_row16_col20 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_634b0_row1_col8 {
#   background-color: #f0402f;
#   color: #f1f1f1;
# }
# #T_634b0_row1_col9, #T_634b0_row2_col20, #T_634b0_row8_col14 {
#   background-color: #fb7a5a;
#   color: #f1f1f1;
# }
# #T_634b0_row1_col10, #T_634b0_row7_col23, #T_634b0_row8_col0 {
#   background-color: #fcb79c;
#   color: #000000;
# }
# #T_634b0_row1_col11, #T_634b0_row5_col10, #T_634b0_row8_col3, #T_634b0_row15_col9 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_634b0_row1_col12, #T_634b0_row11_col17 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_634b0_row1_col13, #T_634b0_row3_col13, #T_634b0_row6_col15, #T_634b0_row7_col15, #T_634b0_row11_col16, #T_634b0_row15_col11 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_634b0_row1_col15, #T_634b0_row5_col4, #T_634b0_row9_col13, #T_634b0_row13_col20 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_634b0_row1_col16, #T_634b0_row7_col9, #T_634b0_row9_col16 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_634b0_row1_col17 {
#   background-color: #fb7353;
#   color: #f1f1f1;
# }
# #T_634b0_row1_col18 {
#   background-color: #c4161c;
#   color: #f1f1f1;
# }
# #T_634b0_row1_col19, #T_634b0_row16_col22 {
#   background-color: #920a13;
#   color: #f1f1f1;
# }
# #T_634b0_row1_col20 {
#   background-color: #75030f;
#   color: #f1f1f1;
# }
# #T_634b0_row1_col22, #T_634b0_row3_col20 {
#   background-color: #6f020e;
#   color: #f1f1f1;
# }
# #T_634b0_row1_col23, #T_634b0_row11_col9 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
# }
# #T_634b0_row2_col1, #T_634b0_row8_col20, #T_634b0_row11_col2 {
#   background-color: #fcc1a8;
#   color: #000000;
# }
# #T_634b0_row2_col2, #T_634b0_row4_col9, #T_634b0_row16_col12 {
#   background-color: #fc9879;
#   color: #000000;
# }
# #T_634b0_row2_col3, #T_634b0_row11_col3, #T_634b0_row12_col15 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_634b0_row2_col4, #T_634b0_row15_col8 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_634b0_row2_col5, #T_634b0_row16_col10 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_634b0_row2_col8, #T_634b0_row9_col5 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_634b0_row2_col9, #T_634b0_row5_col7, #T_634b0_row6_col12, #T_634b0_row8_col22, #T_634b0_row12_col13 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_634b0_row2_col10 {
#   background-color: #fa6849;
#   color: #f1f1f1;
# }
# #T_634b0_row2_col11, #T_634b0_row8_col15, #T_634b0_row11_col6 {
#   background-color: #f75c41;
#   color: #f1f1f1;
# }
# #T_634b0_row2_col12 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_634b0_row2_col13 {
#   background-color: #fc8767;
#   color: #f1f1f1;
# }
# #T_634b0_row2_col14 {
#   background-color: #fc9777;
#   color: #000000;
# }
# #T_634b0_row2_col15, #T_634b0_row3_col4 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_634b0_row2_col16, #T_634b0_row9_col23 {
#   background-color: #fc9c7d;
#   color: #000000;
# }
# #T_634b0_row2_col17 {
#   background-color: #fb7c5c;
#   color: #f1f1f1;
# }
# #T_634b0_row2_col18 {
#   background-color: #f14331;
#   color: #f1f1f1;
# }
# #T_634b0_row2_col19, #T_634b0_row4_col8, #T_634b0_row8_col18, #T_634b0_row14_col15 {
#   background-color: #fb6d4d;
#   color: #f1f1f1;
# }
# #T_634b0_row2_col21, #T_634b0_row6_col10, #T_634b0_row11_col5, #T_634b0_row15_col16 {
#   background-color: #fc8f6f;
#   color: #000000;
# }
# #T_634b0_row2_col22, #T_634b0_row15_col4 {
#   background-color: #f24633;
#   color: #f1f1f1;
# }
# #T_634b0_row2_col23, #T_634b0_row5_col20, #T_634b0_row7_col7 {
#   background-color: #f85d42;
#   color: #f1f1f1;
# }
# #T_634b0_row3_col0, #T_634b0_row14_col1, #T_634b0_row14_col4 {
#   background-color: #f4503a;
#   color: #f1f1f1;
# }
# #T_634b0_row3_col1, #T_634b0_row8_col8 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_634b0_row3_col2, #T_634b0_row9_col9, #T_634b0_row14_col5 {
#   background-color: #fc9e80;
#   color: #000000;
# }
# #T_634b0_row3_col3, #T_634b0_row6_col
